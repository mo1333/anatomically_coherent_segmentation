# %%
from PIL import Image
import glob

# %%
path = "data/REFUGE2/Test/Disc_Masks/"
glob_path = path + "*.png"

count = 0

for img in glob.glob(glob_path):
    print(img)
    Image.open(img).save(path + str(count) + ".png")
    count += 1
# Out:
# data/REFUGE2/Test/Disc_Masks\T0001.png
# data/REFUGE2/Test/Disc_Masks\T0002.png
# data/REFUGE2/Test/Disc_Masks\T0003.png
# data/REFUGE2/Test/Disc_Masks\T0004.png
# data/REFUGE2/Test/Disc_Masks\T0005.png
# data/REFUGE2/Test/Disc_Masks\T0006.png
# data/REFUGE2/Test/Disc_Masks\T0007.png
# data/REFUGE2/Test/Disc_Masks\T0008.png
# data/REFUGE2/Test/Disc_Masks\T0009.png
# data/REFUGE2/Test/Disc_Masks\T0010.png
# data/REFUGE2/Test/Disc_Masks\T0011.png
# data/REFUGE2/Test/Disc_Masks\T0012.png
# data/REFUGE2/Test/Disc_Masks\T0013.png
# data/REFUGE2/Test/Disc_Masks\T0014.png
# data/REFUGE2/Test/Disc_Masks\T0015.png
# data/REFUGE2/Test/Disc_Masks\T0016.png
# data/REFUGE2/Test/Disc_Masks\T0017.png
# data/REFUGE2/Test/Disc_Masks\T0018.png
# data/REFUGE2/Test/Disc_Masks\T0019.png
# data/REFUGE2/Test/Disc_Masks\T0020.png
# data/REFUGE2/Test/Disc_Masks\T0021.png
# data/REFUGE2/Test/Disc_Masks\T0022.png
# data/REFUGE2/Test/Disc_Masks\T0023.png
# data/REFUGE2/Test/Disc_Masks\T0024.png
# ...
